# %% [markdown]
# # Dollar Rial Price 💰

# %% [markdown]
# !["Dollar](image\RvsD.png)

# %% [markdown]
# import libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lls import LinearLeastSquare
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# read and show data :

# %%
data = pd.read_csv("Dollar_Rial_Price_Dataset.csv")
data.head()
# Out:
#    Unnamed: 0        Date Persian_Date    Open     Low    High   Close
# 0           0  11/27/2011   1390/09/06  13,700  13,700  13,700  13,700
# 1           1  11/28/2011   1390/09/07  13,440  13,440  13,440  13,440
# 2           2  11/29/2011   1390/09/08  13,350  13,350  13,350  13,350
# 3           3  11/30/2011   1390/09/09  13,400  13,400  13,400  13,400
# 4           4   12/1/2011   1390/09/10  13,500  13,500  13,500  13,500

# %% [markdown]
# Calculate of Ahmadinejad:

# %% [markdown]
# !["image](image\Mahmoud_Ahmadinejad.png)

# %%
data["Date"] = pd.to_datetime(data["Date"])
# 2011 ---> 2013
df_Mahmod = data[(data["Date"].dt.year >= 2011) & (data["Date"].dt.year <= 2013)]
df_Mahmod["Close"] = pd.to_numeric(df_Mahmod["Close"].str.replace(",", "."))
max_Mahmod = df_Mahmod.sort_values(by="Close",ascending=False).head(1)
min_Mahmod = df_Mahmod.sort_values(by="Close",ascending=True).head(1)

# %%
plt.figure(figsize=(12,6))
plt.title("Disaster of Ahmadinejad")
plt.plot(df_Mahmod["Date"],df_Mahmod["Close"],color="red")
plt.legend(["Dollar price (R)"])
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Calculate of Rouhani:

# %% [markdown]
# !["image"](image\Hasan.png)

# %%
data["Date"] = pd.to_datetime(data["Date"])
# 2013 ---> 2021
df_Hasan = data[(data["Date"].dt.year > 2013) & (data["Date"].dt.year <= 2021)]
df_Hasan["Close"] = pd.to_numeric(df_Hasan["Close"].str.replace(",", "."))
max_Hasan = df_Hasan.sort_values(by="Close",ascending=False).head(1)
min_Hasan = df_Hasan.sort_values(by="Close",ascending=True).head(1)

# %%
plt.figure(figsize=(12,6))
plt.title("Disaster of Rouhani")
plt.plot(df_Hasan["Date"],df_Hasan["Close"],color="purple")
plt.legend(["Dollar price (R)"])
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# Calculator of Raisi :

# %% [markdown]
# !["image"](image\Raisi.png)

# %%
data["Date"] = pd.to_datetime(data["Date"])
# 2021 ---> 2024
df_Ebram = data[(data["Date"].dt.year >= 2021) & (data["Date"].dt.year <= 2024)]
df_Ebram["Close"] = pd.to_numeric(df_Ebram["Close"].str.replace(",", "."))
max_Ebram = df_Ebram.sort_values(by="Close",ascending=False).head(1)
min_Ebram = df_Ebram.sort_values(by="Close",ascending=True).head(1)

# %%
plt.figure(figsize=(12,6))
plt.title("Disaster of Raisi")
plt.plot(df_Ebram["Date"],df_Ebram["Close"],color="green")
plt.legend(["Dollar price (R)"])
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# | President           | Min Price (IRR) | Max Price (IRR) |
# |---------------------|-----------------|-----------------|
# | Mahmoud Ahmadinejad | 1,350           | 3,890           |
# | Hassan Rouhani      | 2,888           | 31,800          |
# | Ebrahim Raisi       | 20,600          | 55,500          |

# %%
data['Date_numeric'] = (data['Date'] - data['Date'].min()).dt.days
data['Close'] = data['Close'].str.replace(',', '').astype(float)

X = data[['Date_numeric']].values  
Y = data['Close'].values

# %%
X_train , X_test , Y_train ,Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
sk_lls = LinearRegression()
sk_lls.fit(X_train,Y_train)
Y_pred = sk_lls.predict(X_test)

# %% [markdown]
# Evaluate each model on test dataset using MAE loss function in Scikit-Learn:

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(Y_test,Y_pred)
# Out:
# 50442.22783840218
